# %% [raw]
# Today’s introduction to geophysical data is: Let’s look at some (simulated) clouds!
#
# get familiar with the cloud computing environment
# use the leap pangeo terminal to see what data I have uploaded onto the cloud storage (see resources from Addisu during bootcamp)
# print a list of files in each of the folders
# check the size of each folder’s contents
# print the size of an individual file (the files we’re looking for have the format cm1out_xxxxxx.nc
#
# open a Jupyter notebook and experiment with loading the data (see code from Pappu above)
# look at the coordinates and their sizes and make sure they make sense to you — these are used to describe the dimensions of the data contained in this netcdf file
# Each coordinate has values that define this dimension — make sure you can print these out or save them to a variable
# Data variables are typically two-dimensional or three-dimensional arrays (I am ignoring the time dimension here because it has a single value for each of these files). take a look at the attributes for each variable. Of particular interest for us at the moment will be qc  and qr  — these are mass mixing ratio for cloud and rain measured in kg of rain/cloud per kg of air (these do not have long names).
# Look at the long_name for sedfluxqc and autoqr — what do these mean?
# make plots of qc and qr — this will be most easily done as slices through the cloud fields. Use xf, yf, zf  to correctly label axes.
# compare data from gs://leap-persistent/mvanlierwalq/dycoms_boss_pr6out_2/cm1out_000063.nc  and gs://leap-persistent/mvanlierwalq/dycoms_boss_pr6out_8/cm1out_000063.nc   what are the main differences you observe between these?
# compare data from gs://leap-persistent/mvanlierwalq/dycoms_boss_pr6out_2/cm1out_000063.nc  and gs://leap-persistent/mvanlierwalq/dycoms_boss_pr6out_2/cm1out_000003.nc  what are the main differences you observe between these?
# Time permitting: write code that calculates the 2D domain-average lwp  (check long_name for this) for each timestep and plots as a line plot, with time axis correctly labeled.
#
#
# @Kaitlyn Loftus will follow up with some guidelines for best practices with plotting

# %%
import xarray as xr
import gcsfs
import matplotlib.pyplot as plt

# %%
# authenticated access using Google Cloud Storage (GCS) file system (GCSFileSystem)
fs = gcsfs.GCSFileSystem()

path = 'gs://leap-persistent/mvanlierwalq/dycoms_boss_pr6out_2/cm1out_000063.nc'

#with fs.open(path, 'rb') as f:     #####xarray does NOT load all data immediately, can create ValueError: I/O operation on closed file
#    ds = xr.open_dataset(f)

########xarray manages the cloud connection internally,
ds = xr.open_dataset(
    "gs://leap-persistent/mvanlierwalq/dycoms_boss_pr6out_2/cm1out_000063.nc",
    engine="h5netcdf",
    backend_kwargs={
        "storage_options": {"token": "cloud"}
    }
)
ds
# Out:
# /tmp/ipykernel_5233/3062194448.py:10: FutureWarning: In a future version, xarray will not decode the variable 'time' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(
# <xarray.Dataset> Size: 164MB
# Dimensions:     (one: 1, time: 1, yh: 128, xh: 128, zh: 96, zf: 97, xf: 129,
#                  yf: 129)
# Coordinates:
#   * time        (time) timedelta64[ns] 8B 05:10:00
#   * yh          (yh) float32 512B 0.025 0.075 0.125 0.175 ... 6.275 6.325 6.375
#   * xh          (xh) float32 512B 0.025 0.075 0.125 0.175 ... 6.275 6.325 6.375
# ...

# %%
#drop last layer
plt.plot(ds.isel(time=0).qc.mean("xh").mean("yh"), ds.zf.isel(zf=slice(0, -1)))

# %%
#drop 1st layer
plt.plot(
    ds.isel(time=0).qc.mean("xh").mean("yh"),
    ds.zf.isel(zf=slice(1, None))
)

# %%
ds.qc.mean("xh").mean("yh").plot(y='zh')

# %%
ds.qc.isel(time=0, yh=64).plot(
    x='xh',
    y='zh'
)

# %%
ds.lwp.mean('xh').mean('yh')
# Out:
# <xarray.DataArray 'lwp' (time: 1)> Size: 4B
# array([0.1010457], dtype=float32)
# Coordinates:
#   * time     (time) timedelta64[ns] 8B 05:10:00
